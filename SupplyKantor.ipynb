# %% [markdown]
# <a href="https://colab.research.google.com/github/mrizkialakbar/UAS_VisualisasiData/blob/main/SupplyKantor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('sample_data/SupplyKantor.csv')

# %%
print(df)
# Out:
#    TanggalPesan        Kota SalesRep    Jenis  Jumlah  Harga Satuan
# 0     30-Mar-17     Jakarta  Richard  Pen Set      62          4990
# 1     07-Apr-17    Surabaya     Nono   Binder      29          1990
# 2     16-Apr-17    Surabaya     Nono  Pen Set      55         12490
# 3     24-Apr-17     Bandung    Susan   Binder      81         19990
# 4     03-May-17    Surabaya    Mamat  Pen Set      42         23950
# 5     11-May-17     Jakarta  Richard   Pencil      35          4990
# 6     20-May-17  Yogyakarta   Jajang     Desk       3        275000
# 7     28-May-17     Bandung    Smith     Desk       2        125000
# 8     06-Jun-17     Bandung     Bobi   Pencil       7          1290
# 9     14-Jun-17     Jakarta  Richard  Pen Set      16         15990
# 10    23-Jun-17  Yogyakarta   Jajang      Pen      76          1990
# 11    01-Jul-17     Bandung   Morgan   Binder      28          8990
# 12    10-Jul-17     Bandung   Thomas   Binder      57         19990
# ...

# %%
x = df['Kota']
y = df['Jumlah']
plt.figure(figsize=(10, 8))
plt.scatter(x, y)

plt.xlabel('Kota')
plt.ylabel('Jumlah')

plt.title('Jumlah Pesanan dari Setiap Kota')

plt.show()

# %%
data_filtered = df [df['Kota']=='Bandung']
data_filtered
# Out:
#    TanggalPesan     Kota SalesRep    Jenis  Jumlah  Harga Satuan
# 3     24-Apr-17  Bandung    Susan   Binder      81         19990
# 7     28-May-17  Bandung    Smith     Desk       2        125000
# 8     06-Jun-17  Bandung     Bobi   Pencil       7          1290
# 11    01-Jul-17  Bandung   Morgan   Binder      28          8990
# 12    10-Jul-17  Bandung   Thomas   Binder      57         19990
# 15    04-Aug-17  Bandung    Susan      Pen      15         19990
# 19    07-Sep-17  Bandung    Smith   Pencil      67          1290
# 21    24-Sep-17  Bandung    Susan  Pen Set      74         15990
# 23    11-Oct-17  Bandung     Bobi   Binder      46          8990
# 25    28-Oct-17  Bandung    Smith   Binder      87         15000
# 28    22-Nov-17  Bandung     Bobi      Pen      27         19990
# 37    07-Feb-18  Bandung     Bobi   Pencil      53          1290
# 38    15-Feb-18  Bandung   Thomas   Pencil      32          1990
# ...

# %%
x = data_filtered['Jenis']
y = data_filtered['Jumlah']
plt.figure(figsize=(10, 8))
plt.scatter(x, y)
plt.xlabel('Jenis Barang')
plt.ylabel('Jumlah')

plt.title('Jumlah Pesanan dari Kota Bandung')

plt.show()

# %%
data_filtered2 = df [df['SalesRep']=='Mamat']
data_filtered2
# Out:
#    TanggalPesan      Kota SalesRep    Jenis  Jumlah  Harga Satuan
# 4     03-May-17  Surabaya    Mamat  Pen Set      42         23950
# 17    21-Aug-17  Surabaya    Mamat  Pen Set      96          4990
# 24    19-Oct-17  Surabaya    Mamat   Binder      50         19990
# 41    13-Mar-18  Surabaya    Mamat     Desk       5        125000

# %%
x = data_filtered2['Jenis']
y = data_filtered2['Jumlah']
plt.figure(figsize=(10, 8))
plt.scatter(x, y)
plt.xlabel('Jenis Barang')
plt.ylabel('Jumlah')

plt.title('Jumlah Pesanan yang dipesan Mamat')

plt.show()

# %%
data_filtered3 = df [df['Jenis']=='Binder']
data_filtered3
# Out:
#    TanggalPesan        Kota SalesRep   Jenis  Jumlah  Harga Satuan
# 1     07-Apr-17    Surabaya     Nono  Binder      29          1990
# 3     24-Apr-17     Bandung    Susan  Binder      81         19990
# 11    01-Jul-17     Bandung   Morgan  Binder      28          8990
# 12    10-Jul-17     Bandung   Thomas  Binder      57         19990
# 16    13-Aug-17    Surabaya     Alex  Binder      11          4990
# 18    30-Aug-17    Surabaya     Alex  Binder      94         19990
# 20    16-Sep-17  Yogyakarta   Rachel  Binder      28          4990
# 23    11-Oct-17     Bandung     Bobi  Binder      46          8990
# 24    19-Oct-17    Surabaya    Mamat  Binder      50         19990
# 25    28-Oct-17     Bandung    Smith  Binder      87         15000
# 27    14-Nov-17     Jakarta  Richard  Binder       4          4990
# 29    01-Dec-17  Yogyakarta   Jajang  Binder       7         19990
# 32    26-Dec-17     Jakarta  Richard  Binder      60          4990
# ...

# %%
x = data_filtered3['Kota']
y = data_filtered3['Jumlah']
plt.figure(figsize=(10, 8))
plt.scatter(x, y)
plt.xlabel('Kota')
plt.ylabel('Jumlah')

plt.title('Jumlah Pesanan Binder')

plt.show()
