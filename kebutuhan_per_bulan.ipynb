# %% [markdown]
# <a href="https://colab.research.google.com/github/mrizkialakbar/mrizk/blob/main/kebutuhan_per_bulan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('kebutuhan_per_bulan_2.csv')

# %%
data_filtered = df [df['Propinsi']=='JAWA TIMUR']
data_filtered
# Out:
#        Propinsi  tahun kebutuhan
# 14   JAWA TIMUR   2005    339227
# 48   JAWA TIMUR   2006    580054
# 82   JAWA TIMUR   2007    458755
# 116  JAWA TIMUR   2008    544157
# 150  JAWA TIMUR   2009    706698
# 184  JAWA TIMUR   2010    856888
# 218  JAWA TIMUR   2011    731635
# 252  JAWA TIMUR   2012    731635
# 286  JAWA TIMUR   2013    825000
# 320  JAWA TIMUR   2014    825000
# 354  JAWA TIMUR   2015    825000

# %%
x = data_filtered['kebutuhan']
y = data_filtered['tahun']
plt.scatter(x, y)

plt.xlabel('Kebutuhan')
plt.ylabel('tahun')

plt.title('DATA KEBUTUHAN PER TAHUN DI JAWA TIMUR')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random

# Membaca dataset dari file CSV
df = pd.read_csv('kebutuhan_per_bulan_2.csv')

# Mengambil subset acak dari data
subset_size = 10  # Jumlah subset yang akan ditampilkan
subset_df = df.sample(n=subset_size, random_state=17)

# Memilih kolom yang akan digunakan sebagai nilai x dan y
x = subset_df['kebutuhan']
y = subset_df['Propinsi']
plt.figure(figsize=(10, 8))
# Membuat scatter plot
plt.scatter(x, y)

# Memberi label sumbu x dan y
plt.xlabel('Kebutuhan')
plt.ylabel('Propinsi')

# Memberi judul grafik
plt.title('Scatter Plot Secara Acak')

# Menampilkan grafik
plt.show()
