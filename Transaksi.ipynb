# %% [markdown]
# <a href="https://colab.research.google.com/github/mrizkialakbar/UAS_VisualisasiData/blob/main/Transaksi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('sample_data/transaksi2.csv')

# %%
print(df)
# Out:
#             Unnamed: 0     id  data1  data2
# 0       5/3/2017 11:43  22704     25  15572
# 1        9/4/2017 7:16  22081     10  12461
# 2       7/9/2017 11:39  22989    100  12590
# 3      3/20/2017 12:18  22629     64  16839
# 4       1/24/2018 8:50  21615      1  13596
# ...                ...    ...    ...    ...
# 7464    1/24/2018 9:17  22510      1  18156
# 7465     2/2/2018 9:49  20771      2  14606
# 7466   3/23/2017 12:52  22493     12  17001
# 7467  10/25/2017 10:28  23118      2  15856
# 7468    7/19/2017 9:54  23184      2  14769
#
# [7469 rows x 4 columns]

# %%
x = df['id']
y = df['data1']
plt.figure(figsize=(10, 8))
plt.scatter(x, y)

plt.xlabel('id')
plt.ylabel('Data1')
plt.xticks(rotation=90, fontsize=8)

plt.title('Scatter pot dari datasets')

plt.show()

# %%
x = df['id']
y = df['data2']
plt.figure(figsize=(10, 8))
plt.scatter(x, y)

plt.xlabel('id')
plt.ylabel('Data2')
plt.xticks(rotation=90, fontsize=8)

plt.title('Scatter pot dari datasets')

plt.show()
